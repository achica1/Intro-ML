# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'C:\Users\achic\OneDrive\Desktop\ML-DataSets/D3.csv')
df.head()
m = len(df)

# %%
def compute_cost(X,y,theta):
    predictions = X.dot(theta)
    errors = np.subtract(predictions, y)
    sqrErrors = np.square(errors)
    J = 1 / (2 * m) * np.sum(sqrErrors)
    return J
    
def gradient_descent(X, y, theta, alpha, iterations):
    cost_history = np.zeros(iterations)
    for i in range(iterations):
        predictions = X.dot(theta)
        errors = np.subtract(predictions, y)
        sum_delta = (alpha / m) * X.transpose().dot(errors);
        theta = theta - sum_delta;
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# %%
#theta = [0., 0.]
iterations = 1500; 
alpha = 0.01;

# %%
# Training for X1

X1 = df.values[:, 0]  # get input values from first column
y = df.values[:, 3]  # get output values from fourth column

X1_0 = np.ones((m, 1))
X1_1 = X1.reshape(m, 1)
X1 = np.hstack((X1_0, X1_1))
theta1 = np.zeros(2)
theta1, cost_history1 = gradient_descent(X1, y, theta1, alpha, iterations)

print(' Final value of theta1 = ', theta1)
print('cost_history1 =', cost_history1)


# Plot Linear regression for X1
# Since X is list of list (feature matrix) lets take values of column of index 1 only 

plt.scatter(X1[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X1[:,1],X1.dot(theta1), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Variable X1') 
plt.ylabel('Target y') 
plt.title('Linear Regression Fit for X1') 
plt.legend()
# Out:
#  Final value of theta1 =  [ 5.71850653 -1.9568206 ]
# cost_history1 = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
# Gradient Descent Model for X1

#plt.figure(2)
plt.plot(range(1, iterations + 1),cost_history1, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J)') 
plt.title('Convergence of gradient descent')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent')

# %%
# Training for X2

X2 = df.values[:, 1]  # get input values from second column
y = df.values[:, 3]  # get output values from fourth column

X2_0 = np.ones((m, 1))
X2_1 = X2.reshape(m, 1)
X2 = np.hstack((X2_0, X2_1))

theta2 = np.zeros(2)

theta2, cost_history2 = gradient_descent(X2, y, theta2, alpha, iterations)

print(' theta2 value = ', theta2)
print('cost_history2 =', cost_history2)



# Plot Linear regression for X1
# Since X is list of list (feature matrix) lets take values of column of index 1 only 
#plt.figure(3)

plt.scatter(X2[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X2[:,1],X2.dot(theta2), color='green', label='Linear Regression')
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Variable X2') 
plt.ylabel('Target y') 
plt.title('Linear Regression Fit for X2') 
plt.legend()
# Out:
#  theta2 value =  [0.71988473 0.56390334]
# cost_history2 = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
# Gradien Descent Model for X2

#plt.figure(4)

plt.plot(range(1, iterations + 1),cost_history2, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J)') 
plt.title('Convergence of gradient descent for X2')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X2')

# %%
# Training for X3
X3 = df.values[:, 2]  # get input values from second column
y = df.values[:, 3]  # get output values from fourth column

X3_0 = np.ones((m, 1))
X3_1 = X3.reshape(m, 1)
X3 = np.hstack((X3_0, X3_1))

theta3 = np.zeros(2)

theta3, cost_history3 = gradient_descent(X3, y, theta3, alpha, iterations)

print(' theta3 value = ', theta3)
print('cost_history3 =', cost_history3)


# Plot Linear regression for X3
# Since X is list of list (feature matrix) lets take values of column of index 1 only 
#plt.figure(5)
plt.scatter(X3[:,1], y, color='red', marker= '+', label= 'Training Data')
plt.plot(X3[:,1],X3.dot(theta3), color='green', label='Linear Regression')

plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Variable X3') 
plt.ylabel('Target y') 
plt.title('Linear Regression Fit for X3') 
plt.legend()
# Out:
#  theta3 value =  [ 2.78048129 -0.48451631]
# cost_history3 = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
# Gradien Descent Model for X3
plt.plot(range(1, iterations + 1),cost_history3, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J)') 
plt.title('Convergence of gradient descent for X3')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X3')

# %%
x = df.values[:, :3]
x = np.hstack((np.ones((m, 1)), x.reshape(m, 3)))

theta = np.zeros(4)
theta, cost_history = gradient_descent(x, y, theta, alpha, iterations)

print(' Final theta value = ', theta)
print('cost_history =', cost_history)
# Out:
#  Final theta value =  [ 4.15118728 -1.8394291   0.72473856 -0.09513266]
# cost_history = [5.21542243 4.97171977 4.7765543  ... 0.81079843 0.81065429 0.81051044]

# %%
# Predict y values for each X variable
y1 = theta.dot(np.array([1, 1, 1, 1]))
y2 = theta.dot(np.array([1, 2, 0, 4]))
y3 = theta.dot(np.array([1, 3, 2, 1]))
print('Value y1 = ', y1) 
print('Value y2 = ', y2) 
print('Value y3 = ', y3)
# Out:
# Value y1 =  2.9413640816645295
# Value y2 =  0.09179843075891547
# Value y3 =  -0.012755552822328653

# %%
plt.plot(range(1, iterations + 1),cost_history, color='blue') 
plt.rcParams["figure.figsize"] = (10,6) 
plt.grid() 
plt.xlabel('Number of iterations') 
plt.ylabel('Cost (J)') 
plt.title('Convergence of gradient descent for X1, X2, and X3 ')
# Out:
# Text(0.5, 1.0, 'Convergence of gradient descent for X1, X2, and X3 ')
